# %% [markdown]
# # first_time_auth
# Run this notebook **once** interactively to obtain the initial Blackbaud OAuth
# tokens and save the refresh token into the Domo account store.
# Do **not** schedule this notebook.

# %%
# %run user_configuration.ipynb
# %run renxt_core.ipynb

# %%
# Opens a browser auth URL → paste the full redirect URL back here.
# The refresh token is then written to the re_creds Domo account automatically.
tokens = authorize_interactive()
print("\nDone. You can now schedule the pipeline notebooks.")
