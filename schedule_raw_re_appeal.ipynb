# %% [markdown]
# # schedule_raw_re_appeal
# Incremental sync: `appeal` → `6bbcf6f9-8d6c-47dc-9724-5101f1ee90b3`
#
# Full replace — no incremental field on this endpoint.

# %%
# %run user_configuration.ipynb
# %run renxt_core.ipynb

# %%
ENDPOINT_NAME = "appeal"
DAYS_BACK     = 0   # 0 = full historic pull; 1+ = incremental
DATASET_ID    = "6bbcf6f9-8d6c-47dc-9724-5101f1ee90b3"
UPDATE_METHOD = "REPLACE"   # 'smart_upsert' | 'REPLACE'
MERGE_KEY     = "id"

# %%
df = run_incremental(
    endpoint_name   = ENDPOINT_NAME,
    days_back       = DAYS_BACK,
    domo_dataset_id = DATASET_ID,
    update_method   = UPDATE_METHOD,
    merge_key       = MERGE_KEY,
)
print(f"\nFinal shape: {df.shape}")
