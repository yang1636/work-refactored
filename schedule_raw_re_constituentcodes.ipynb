# %% [markdown]
# # schedule_raw_re_constituentcodes
# Incremental sync: `constituentcodes` → `e76d5758-c364-4eca-a52a-0e2953a8fbe8`

# %%
# %run user_configuration.ipynb
# %run renxt_core.ipynb

# %%
ENDPOINT_NAME = "constituentcodes"
DATASET_ID    = "e76d5758-c364-4eca-a52a-0e2953a8fbe8"
UPDATE_METHOD = "smart_upsert"   # 'smart_upsert' | 'REPLACE'
MERGE_KEY     = "id"

# %%
df = run_incremental(
    endpoint_name   = ENDPOINT_NAME,
    domo_dataset_id = DATASET_ID,
    update_method   = UPDATE_METHOD,
    merge_key       = MERGE_KEY,
)
print(f"\nFinal shape: {df.shape}")
