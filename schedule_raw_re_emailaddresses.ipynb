# %% [markdown]
# # schedule_raw_re_emailaddresses
# Incremental sync: `emailaddresses` → `02d4c77f-0cb7-4661-9ff1-6d56201074e9`
#
# Endpoint name is `emailaddresses` (no underscore) — matches /constituent/v1/emailaddresses.

# %%
# %run user_configuration.ipynb
# %run renxt_core.ipynb

# %%
ENDPOINT_NAME = "emailaddresses"
DATASET_ID    = "02d4c77f-0cb7-4661-9ff1-6d56201074e9"
UPDATE_METHOD = "smart_upsert"   # 'smart_upsert' | 'REPLACE'
MERGE_KEY     = "id"

# %%
df = run_incremental(
    endpoint_name   = ENDPOINT_NAME,
    domo_dataset_id = DATASET_ID,
    update_method   = UPDATE_METHOD,
    merge_key       = MERGE_KEY,
)
print(f"\nFinal shape: {df.shape}")
