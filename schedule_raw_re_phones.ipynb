# %% [markdown]
# # schedule_raw_re_phones
# Incremental sync: `phones` → `99786b37-4f18-432e-b003-ca24e79a2c2f`

# %%
# %run user_configuration.ipynb
# %run renxt_core.ipynb

# %%
ENDPOINT_NAME = "phones"
DAYS_BACK     = 1   # 0 = full historic pull; 1+ = incremental
DATASET_ID    = "99786b37-4f18-432e-b003-ca24e79a2c2f"
UPDATE_METHOD = "smart_upsert"   # 'smart_upsert' | 'REPLACE'
MERGE_KEY     = "id"

# %%
df = run_incremental(
    endpoint_name   = ENDPOINT_NAME,
    days_back       = DAYS_BACK,
    domo_dataset_id = DATASET_ID,
    update_method   = UPDATE_METHOD,
    merge_key       = MERGE_KEY,
)
print(f"\nFinal shape: {df.shape}")
